# %%
import pandas as pd
import plotly as plt

# %%
nSteps = 10
vol = 0.2
veryLongRegression = pd.read_csv(f"/home/leon/projects/epsilon-ensemble/data/autorergression{nSteps}-{vol}.txt", sep="\n", header=None)
plt.plot(veryLongRegression, "line")
# Out:
# <div>
#
#
#             <div id="634dcf76-44f4-446d-9b4e-7fb02df0b251" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("634dcf76-44f4-446d-9b4e-7fb02df0b251")) {
#                     Plotly.newPlot(
#                         '634dcf76-44f4-446d-9b4e-7fb02df0b251',
# ...

# %%
longRegression = pd.read_csv("/home/leon/projects/epsilon-ensemble/data/autorergression10-0,15.txt", sep="\n", header=None)
plt.plot(longRegression, "line")
# Out:
# <div>
#
#
#             <div id="4c96eed0-85a6-4b51-922d-abe3a0b89eb1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4c96eed0-85a6-4b51-922d-abe3a0b89eb1")) {
#                     Plotly.newPlot(
#                         '4c96eed0-85a6-4b51-922d-abe3a0b89eb1',
# ...

# %%
shortRegression = pd.read_csv("/home/leon/projects/epsilon-ensemble/data/autorergression3-0,2.txt", sep="\n", header=None)
plt.plot(shortRegression, "line")
# Out:
# <div>
#
#
#             <div id="dbfee4ae-b30b-40fa-9cc9-33d379ab8cd2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("dbfee4ae-b30b-40fa-9cc9-33d379ab8cd2")) {
#                     Plotly.newPlot(
#                         'dbfee4ae-b30b-40fa-9cc9-33d379ab8cd2',
# ...
